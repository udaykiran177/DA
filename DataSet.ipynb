# %%
import pandas as pd
import numpy as np

# %%
m=pd.read_csv('Z:\\DA\\files\\Iris1.csv')

# %%
m
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      1            5.1           3.5            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
print(len(m))#no of rows
print(len(list(m.head(1)))) #no of cols
# Out:
# 150
# 6

# %%
# m.duplicated()
m['Dup_Bol']=m.duplicated()

l=[]
for i in range(len(m)):
    if m.loc[i]['Dup_Bol']:
        l.append(m.loc[i])
    print(list(m.loc[i]))
print('duplicated')
print(l)
# Out:
# [1, 5.1, 3.5, 1.4, 0.2, 'Iris-setosa', False]
# [1, 5.1, 3.5, 1.4, 0.2, 'Iris-setosa', True]
# [3, 4.7, 3.2, 1.3, 0.2, 'Iris-setosa', False]
# [4, 4.6, 3.1, 1.5, 0.2, 'Iris-setosa', False]
# [5, 5.0, 3.6, 1.4, 0.2, 'Iris-setosa', False]
# [6, 5.4, 3.9, 1.7, 0.4, 'Iris-setosa', False]
# [7, 4.6, 3.4, 1.4, 0.3, 'Iris-setosa', False]
# [8, 5.0, 3.4, 1.5, 0.2, 'Iris-setosa', False]
# [9, 4.4, 2.9, 1.4, 0.2, 'Iris-setosa', False]
# [10, 4.9, 3.1, 1.5, 0.1, 'Iris-setosa', False]
# [11, 5.4, 3.7, 1.5, 0.2, 'Iris-setosa', False]
# [12, 4.8, 3.4, 1.6, 0.2, 'Iris-setosa', False]
# [13, 4.8, 3.0, 1.4, 0.1, 'Iris-setosa', False]
# [14, 4.3, 3.0, 1.1, 0.1, 'Iris-setosa', False]
# [15, 5.8, 4.0, 1.2, 0.2, 'Iris-setosa', False]
# [16, 5.7, 4.4, 1.5, 0.4, 'Iris-setosa', False]
# [17, 5.4, 3.9, 1.3, 0.4, 'Iris-setosa', False]
# [18, 5.1, 3.5, 1.4, 0.3, 'Iris-setosa', False]
# [19, 5.7, 3.8, 1.7, 0.3, 'Iris-setosa', False]
# [20, 5.1, 3.8, 1.5, 0.3, 'Iris-setosa', False]
# ...
